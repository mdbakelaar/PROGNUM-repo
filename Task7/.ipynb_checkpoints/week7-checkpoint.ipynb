# %% [markdown]
# Question 7.1

# %%
import numpy as np
from numpy import linalg as la
from numpy.linalg import inv

# We want to suppress printing of small floating point values using scientific notation
np.set_printoptions(suppress=True)

#making the matrix A
A = np.array([1,2, 3, 0, -4, 1, 0, 3, -1]).reshape(3,3)
print("A=")
print(A)

#getting the determinant of the matrix
det = la.det(A)
print(f"Determinant of A is: {det:.6f}")

#calculating the solution to the set of equations
b = np.array([2,2,-1])
Ainv = inv(A)
xyz = Ainv@b
print(f"\nSolution: x, y, z = {xyz}")
print(f"\nShorter: x, y, z = la.inv(A).dot(b) = {inv(A)@b}")

#all the ways to check if A is orthogonal
print(f"\nA.AT should be the identity matrix:\n{A@A.T}\n{A@A.T == np.identity(3)}")
print(f"\nInverse of A:\n{inv(A)}")
print(f"\nis equal to the transpose:\n{A.T}")
print(f"\nAlternative check with function array_equal(): {np.array_equal(A.T, inv(A))}")
print(f"\nAlternative check with function allclose(): {np.allclose(A.T, inv(A))}")
print("No the matrix A is not orthogonal")

#getting the eigenvalues of A
Lambda, v = la.eig(A)
print("Lambda = ", Lambda)
print(f"\nEigenvectors:\n{v}")

# Unpack the three vectors
v1, v2, v3 = v.T
print(v1)
print(v2)
print(v3)
print("\nProof of (A.v == Lambda.v):")
print(np.allclose(A@v1, Lambda[0]*v1))
print(np.allclose(A@v2, Lambda[1]*v2))
print(np.allclose(A@v3, Lambda[2]*v3))
# Out:
# A=
# [[ 1  2  3]
#  [ 0 -4  1]
#  [ 0  3 -1]]
# Determinant of A is: 1.000000
#
# Solution: x, y, z = [10. -1. -2.]
#
# Shorter: x, y, z = la.inv(A).dot(b) = [10. -1. -2.]
#
# A.AT should be the identity matrix:
# [[ 14  -5   3]
#  [ -5  17 -13]
#  [  3 -13  10]]
# [[False False False]
#  [False False False]
#  [False False False]]
#
# Inverse of A:
# [[ 1. 11. 14.]
#  [-0. -1. -1.]
#  [-0. -3. -4.]]
#
# is equal to the transpose:
# [[ 1  0  0]
#  [ 2 -4  3]
#  [ 3  1 -1]]
#
# Alternative check with function array_equal(): False
#
# Alternative check with function allclose(): False
# No the matrix A is not orthogonal
# Lambda =  [ 1.         -4.79128785 -0.20871215]
#
# Eigenvectors:
# [[ 1.         -0.05055961  0.94256676]
#  [ 0.         -0.78318743 -0.08518794]
#  [ 0.          0.6197267  -0.32297201]]
# [1. 0. 0.]
# [-0.05055961 -0.78318743  0.6197267 ]
# [ 0.94256676 -0.08518794 -0.32297201]
#
# Proof of (A.v == Lambda.v):
# True
# True
# True

# %% [markdown]
# Question 7.3

# %%
import numpy as np
from numpy import linalg as la
from numpy.linalg import inv


def Ex(angle_deg):
    a = np.radians(angle_deg)
    return np.array([
        [1, 0, 0],
        [0, np.cos(a), np.sin(a)],
        [0, -np.sin(a),  np.cos(a)]
    ])

def Ey(angle_deg):
    a = np.radians(angle_deg)
    return np.array([
        [ np.cos(a), 0, -np.sin(a)],
        [ 0,         1, 0        ],
        [np.sin(a), 0, np.cos(a)]
    ])

def Ez(angle_deg):
    a = np.radians(angle_deg)
    return np.array([
        [np.cos(a), np.sin(a), 0],
        [-np.sin(a),  np.cos(a), 0],
        [0,          0,         1]
    ])

E = Ez(180 - 123) @ Ey(90 - 27.4) @ Ez(192.25)
print(E)


#if it is a rotation matrix it should be orthogonal which we can prove using:
print(f"\nInverse of E:\n{inv(E)}")
print(f"\nis equal to the transpose:\n{E.T}")
print(f"\nAlternative check with function allclose(): {np.allclose(E.T, inv(E))}")

Lambda, v = la.eig(E)
print("Lambda = ", Lambda)
print(f"\nEigenvectors:\n{v}")
# Out:
# [[-0.06698874 -0.87275577 -0.48353891]
#  [ 0.49272847 -0.45034696  0.74458463]
#  [-0.86760081 -0.1883746   0.46019978]]
#
# Inverse of E:
# [[-0.06698874  0.49272847 -0.86760081]
#  [-0.87275577 -0.45034696 -0.1883746 ]
#  [-0.48353891  0.74458463  0.46019978]]
#
# is equal to the transpose:
# [[-0.06698874  0.49272847 -0.86760081]
#  [-0.87275577 -0.45034696 -0.1883746 ]
#  [-0.48353891  0.74458463  0.46019978]]
#
# Alternative check with function allclose(): True
# Lambda =  [-0.52856796+0.84889099j -0.52856796-0.84889099j  1.        +0.j        ]
#
# Eigenvectors:
# [[ 0.09023842+0.58384315j  0.09023842-0.58384315j -0.54951651+0.j        ]
#  [ 0.68877691+0.j          0.68877691-0.j          0.22621391+0.j        ]
#  [-0.13207344+0.39890747j -0.13207344-0.39890747j  0.80427537+0.j        ]]

# %%
import numpy as np
from numpy import linalg as la

def Ex(angle_deg):
    a = np.radians(angle_deg)
    return np.array([
        [1, 0, 0],
        [0, np.cos(a), np.sin(a)],
        [0, -np.sin(a), np.cos(a)]
    ])

def Ey(angle_deg):
    a = np.radians(angle_deg)
    return np.array([
        [np.cos(a), 0, -np.sin(a)],
        [0, 1, 0],
        [np.sin(a), 0, np.cos(a)]
    ])

def Ez(angle_deg):
    a = np.radians(angle_deg)
    return np.array([
        [np.cos(a), np.sin(a), 0],
        [-np.sin(a), np.cos(a), 0],
        [0, 0, 1]
    ])

# Create the composed matrix E
E = Ez(180 - 123) @ Ey(90 - 27.4) @ Ez(192.25)
print("Composed Matrix E:\n", E)
# Out:
# Composed Matrix E:
#  [[-0.06698874 -0.87275577 -0.48353891]
#  [ 0.49272847 -0.45034696  0.74458463]
#  [-0.86760081 -0.1883746   0.46019978]]

# %%
import numpy as np
from numpy import linalg as la

def Ex(angle_deg):
    a = np.radians(angle_deg)
    return np.array([
        [1, 0, 0],
        [0, np.cos(a), np.sin(a)],
        [0, -np.sin(a), np.cos(a)]
    ])

def Ey(angle_deg):
    a = np.radians(angle_deg)
    return np.array([
        [np.cos(a), 0, -np.sin(a)],
        [0, 1, 0],
        [np.sin(a), 0, np.cos(a)]
    ])

def Ez(angle_deg):
    a = np.radians(angle_deg)
    return np.array([
        [np.cos(a), np.sin(a), 0],
        [-np.sin(a), np.cos(a), 0],
        [0, 0, 1]
    ])

# Create the composed matrix E
E = Ez(180 - 123) @ Ey(90 - 27.4) @ Ez(192.25)
print("Composed Matrix E:\n", E)

# --- PROOF 1: Rotation Matrix ---
is_orthogonal = np.allclose(E.T @ E, np.eye(3))
det_E = la.det(E)
print(f"\nIs E orthogonal? {is_orthogonal}")
print(f"Determinant of E: {det_E:.1f}")

# --- PROOF 2: Eigenvalues ---
lambdas, eig_vecs = la.eig(E)
print(f"\nEigenvalues: {lambdas}")
# Check if one of them is approximately 1.0
has_one = np.any(np.isclose(lambdas, 1.0))
print(f"Has eigenvalue of 1? {has_one}")

# --- PROOF 3: Vector v ---
v = np.array([-0.86760081, -0.1883746, 0.46019978])
norm_v = la.norm(v)
print(f"\nNorm of v: {norm_v:.4f}")

# --- PROOF 4: Rotate v to Galactic System ---
v2 = E @ v
print(f"Resulting vector v2 (Galactic System): {v2.round(4)}")
# Out:
# Composed Matrix E:
#  [[-0.06698874 -0.87275577 -0.48353891]
#  [ 0.49272847 -0.45034696  0.74458463]
#  [-0.86760081 -0.1883746   0.46019978]]
#
# Is E orthogonal? True
# Determinant of E: 1.0
#
# Eigenvalues: [-0.52856796+0.84889099j -0.52856796-0.84889099j  1.        +0.j        ]
# Has eigenvalue of 1? True
#
# Norm of v: 1.0000
# Resulting vector v2 (Galactic System): [ 0. -0.  1.]

# %% [markdown]
# Question 7.5

# %%
import numpy as np
from numpy.linalg import solve

x = np.array([1.2, 2.0, 3.1, 4.4, 4.9, 5.8, 6.9, 8.0, 9.1, 9.9])
y = np.array([0.3, 0.5, 0.7, 0.8, 1.3, 1.6, 2.0, 2.3, 2.9, 3.0])



a = np.linalg.solve(A, y)
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       4 x = np.array([1.2, 2.0, 3.1, 4.4, 4.9, 5.8, 6.9, 8.0, 9.1, 9.9])
#       5 y = np.array([0.3, 0.5, 0.7, 0.8, 1.3, 1.6, 2.0, 2.3, 2.9, 3.0])
# ----> 7 a = np.linalg.solve(A, y)
#       8 print(a)
#
# NameError: name 'A' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Data Points
x = np.array([1.2, 2.0, 3.1, 4.4, 4.9, 5.8, 6.9, 8.0, 9.1, 9.9])
y = np.array([0.3, 0.5, 0.7, 0.8, 1.3, 1.6, 2.0, 2.3, 2.9, 3.0])

def interpolate_poly(x, y):
    n = len(x)
    # 2. Construct the Vandermonde matrix V using loops
    V = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            V[i, j] = x[i]**j
    
    # 3. Solve the linear system V * a = y
    # a contains the coefficients [a0, a1, a2, ..., an-1]
    a = np.linalg.solve(V, y)
    return a

# Get coefficients
coeffs = interpolate_poly(x, y)

# 4. Generate points for a smooth plot
x_plot = np.linspace(min(x), max(x), 500)
y_plot = np.zeros_like(x_plot)

# Evaluate the polynomial using the solved coefficients
for i in range(len(coeffs)):
    y_plot += coeffs[i] * (x_plot**i)

# 5. Plotting
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='red', label='Data Points', zorder=5)
plt.plot(x_plot, y_plot, label=f'Interpolating Poly (deg {len(x)-1})', color='blue')
plt.title("Polynomial Interpolation")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Question 7.6

# %% [markdown]
# Question 7.7

# %% [markdown]
# Question 7.10

# %% [markdown]
# Question 7.14

# %% [markdown]
# Week 8 question 8.1
