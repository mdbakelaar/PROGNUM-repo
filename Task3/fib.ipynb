# %%
fib = 1
i = 0
k = 1
n = input("Enter an integer that' s higher than the fibonacci numbers you want: ")
N = int(n)                                                                         #Making an integer of the input value
m = input("Enter an iteger that the fibonacci numbers will be divided by: ")
M = int(m)


while k < 100:                                                                     #Making a fibonacci sequence
    i, fib = fib, i + fib
    k += 1
    if fib < N and fib/M - int(fib/M) == 0:                                        #Giving the conditions it needs to follow
        print(fib)
