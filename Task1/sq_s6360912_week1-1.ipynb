# %% [markdown]
# Answers for week 1
#
# * name: Marit Bakelaar
# * username: mdbakelaar
# * S-number: S6360912
# * group: As4

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %%
x = 6
print(x)
x *= 6
print(x)
x =x* 6
# Out:
# 6
# 36

# %% [markdown]
# ![kat.png](attachment:8b44ca63-57b1-444d-8a87-2ab172d0265d.png)

# %%
x = 5
x *= 4
x *= 3
x *= 2
print (x)
# Out:
# 120

# %%
from scipy.constants import c
print (c)
from scipy.constants import h
print (h)
f = 2.42*10**28
l = c/f 

E = h * c / l
print (E)
# Out:
# 299792458.0
# 6.62607015e-34
# 1.6035089762999996e-05

# %%
from scipy.constants import G
print (G)

m = 7.342*10**22
M = 5.9722*10**24
r = 385000.6

F = G * (m * M)/r**2
print (F)
# Out:
# 6.6743e-11
# 1.9743840518075714e+26

# %%
x1 = 10
x2 = 22/7

print(x1, end=" ")
print(x2, end="")
# Out:
# 10 3.142857142857143

# %% [markdown]
# ![myfirstpy screenshot.png](attachment:a4c95e9f-2177-4150-b099-dc2c34192d6d.png)

# %% [markdown]
# 1.15
# 1) pwd will print the absolute path of the directory you are currently in
# 2) . stands for the current directory and .. stands for the ' parent ' directory. so the one that came before
#
# 1.16
# the shortest command to go back to the desktop/ home directory is cd ~/

# %% [markdown]
# ![Screenshot from 2026-02-13 13-05-10.png](attachment:d7989887-4aff-4bd8-a0af-3f0edf8b8c69.png)

# %% [markdown]
# 1.19
# 1) The command ls *[0-9]*.[co]. gives all files containing a number between 0-9 and containing either a 'c' or an 'o'
# 2) to give the range
# 3) The command ls *[0-9]*.co will only give files that end with .co and contain the numbers 0-9
