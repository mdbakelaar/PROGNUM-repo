# %%
# Sirius data
apparentMagnitude = -1.46
absoluteMagnitude = 1.45

# The distance is related to the magnitudes as m-M=5.Log(d/10)
# 1 Parsec = 3.26164 ly

m = apparentMagnitude
M = absoluteMagnitude

d = 10.0 * pow( 10.0, (m-M)/5.0 ) * 3.26164
b = f"An approximation for the distance to sirius a is: {d}"
print(b)
# Out:
# An approximation for the distance to sirius a is: 8.53957042692737

# %%
# Sirius data
apparentMagnitude = input("Enter an integer: ")
absoluteMagnitude = input("Enter an integer: ")

# The distance is related to the magnitudes as m-M=5.Log(d/10)
# 1 Parsec = 3.26164 ly

m = int(apparentMagnitude)
M = int(absoluteMagnitude)
print(m, type(m))
print(M, type(M))

d = 10.0 * pow( 10.0, (m-M)/5.0 ) * 3.26164
b = f"An approximation for the distance to an arbitrary star is: {d}"
print(b)
# Out:
# Enter an integer:  3
# Enter an integer:  -2
# 3 <class 'int'>
# -2 <class 'int'>
# An approximation for the distance to an arbitrary star is: 326.164
